# %%
# Modify the jpg input, take the result.

# !mkdir -p _temp
# !echo `pwd`/images/cat.jpg > _temp/det_input.txt
# !echo `pwd`
# !../python/detect.py --crop_mode=selective_search \
  --pretrained_model=/Users/wuchenglin/git/caffe/models/bvlc_reference_rcnn_ilsvrc13/bvlc_reference_rcnn_ilsvrc13.caffemodel \
  --model_def=/Users/wuchenglin/git/caffe/models/bvlc_reference_rcnn_ilsvrc13/deploy.prototxt \
  --raw_scale=255 _temp/det_input.txt _temp/det_output.h5
# Out:
# /Users/wuchenglin/git/caffe/examples
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I1208 15:12:23.558094 1908544256 net.cpp:39] Initializing net from parameters:
# name: "R-CNN-ilsvrc13"
# layers {
#   bottom: "data"
#   top: "conv1"
#   name: "conv1"
#   type: CONVOLUTION
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#   }
# }
# layers {
#   bottom: "conv1"
#   top: "conv1"
#   name: "relu1"
#   type: RELU
# }
# layers {
#   bottom: "conv1"
#   top: "pool1"
#   name: "pool1"
#   type: POOLING
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layers {
#   bottom: "pool1"
#   top: "norm1"
#   name: "norm1"
#   type: LRN
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layers {
#   bottom: "norm1"
#   top: "conv2"
#   name: "conv2"
#   type: CONVOLUTION
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#   }
# }
# layers {
#   bottom: "conv2"
#   top: "conv2"
#   name: "relu2"
#   type: RELU
# }
# layers {
#   bottom: "conv2"
#   top: "pool2"
#   name: "pool2"
#   type: POOLING
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layers {
#   bottom: "pool2"
#   top: "norm2"
#   name: "norm2"
#   type: LRN
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layers {
#   bottom: "norm2"
#   top: "conv3"
#   name: "conv3"
#   type: CONVOLUTION
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#   }
# }
# layers {
#   bottom: "conv3"
#   top: "conv3"
#   name: "relu3"
#   type: RELU
# }
# layers {
#   bottom: "conv3"
#   top: "conv4"
#   name: "conv4"
#   type: CONVOLUTION
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#   }
# }
# layers {
#   bottom: "conv4"
#   top: "conv4"
#   name: "relu4"
#   type: RELU
# }
# layers {
#   bottom: "conv4"
#   top: "conv5"
#   name: "conv5"
#   type: CONVOLUTION
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#   }
# }
# layers {
#   bottom: "conv5"
#   top: "conv5"
#   name: "relu5"
#   type: RELU
# }
# layers {
#   bottom: "conv5"
#   top: "pool5"
#   name: "pool5"
#   type: POOLING
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layers {
#   bottom: "pool5"
#   top: "fc6"
#   name: "fc6"
#   type: INNER_PRODUCT
#   inner_product_param {
#     num_output: 4096
#   }
# }
# layers {
#   bottom: "fc6"
#   top: "fc6"
#   name: "relu6"
#   type: RELU
# }
# layers {
#   bottom: "fc6"
#   top: "fc6"
#   name: "drop6"
#   type: DROPOUT
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layers {
#   bottom: "fc6"
#   top: "fc7"
#   name: "fc7"
#   type: INNER_PRODUCT
#   inner_product_param {
#     num_output: 4096
#   }
# }
# layers {
#   bottom: "fc7"
#   top: "fc7"
#   name: "relu7"
#   type: RELU
# }
# layers {
#   bottom: "fc7"
#   top: "fc7"
#   name: "drop7"
#   type: DROPOUT
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layers {
#   bottom: "fc7"
#   top: "fc-rcnn"
#   name: "fc-rcnn"
#   type: INNER_PRODUCT
#   inner_product_param {
#     num_output: 200
#   }
# }
# input: "data"
# input_dim: 10
# input_dim: 3
# input_dim: 227
# input_dim: 227
# I1208 15:12:23.559114 1908544256 net.cpp:358] Input 0 -> data
# I1208 15:12:23.559142 1908544256 net.cpp:67] Creating Layer conv1
# I1208 15:12:23.559160 1908544256 net.cpp:394] conv1 <- data
# I1208 15:12:23.559166 1908544256 net.cpp:356] conv1 -> conv1
# I1208 15:12:23.559175 1908544256 net.cpp:96] Setting up conv1
# I1208 15:12:23.559207 1908544256 net.cpp:103] Top shape: 10 96 55 55 (2904000)
# I1208 15:12:23.559221 1908544256 net.cpp:67] Creating Layer relu1
# I1208 15:12:23.559234 1908544256 net.cpp:394] relu1 <- conv1
# I1208 15:12:23.559239 1908544256 net.cpp:345] relu1 -> conv1 (in-place)
# I1208 15:12:23.559244 1908544256 net.cpp:96] Setting up relu1
# I1208 15:12:23.559247 1908544256 net.cpp:103] Top shape: 10 96 55 55 (2904000)
# I1208 15:12:23.559253 1908544256 net.cpp:67] Creating Layer pool1
# I1208 15:12:23.559257 1908544256 net.cpp:394] pool1 <- conv1
# I1208 15:12:23.559260 1908544256 net.cpp:356] pool1 -> pool1
# I1208 15:12:23.559265 1908544256 net.cpp:96] Setting up pool1
# I1208 15:12:23.559274 1908544256 net.cpp:103] Top shape: 10 96 27 27 (699840)
# I1208 15:12:23.559279 1908544256 net.cpp:67] Creating Layer norm1
# I1208 15:12:23.559283 1908544256 net.cpp:394] norm1 <- pool1
# I1208 15:12:23.559286 1908544256 net.cpp:356] norm1 -> norm1
# I1208 15:12:23.559293 1908544256 net.cpp:96] Setting up norm1
# I1208 15:12:23.559298 1908544256 net.cpp:103] Top shape: 10 96 27 27 (699840)
# I1208 15:12:23.559461 1908544256 net.cpp:67] Creating Layer conv2
# I1208 15:12:23.559471 1908544256 net.cpp:394] conv2 <- norm1
# I1208 15:12:23.559478 1908544256 net.cpp:356] conv2 -> conv2
# I1208 15:12:23.559487 1908544256 net.cpp:96] Setting up conv2
# I1208 15:12:23.560106 1908544256 net.cpp:103] Top shape: 10 256 27 27 (1866240)
# I1208 15:12:23.560129 1908544256 net.cpp:67] Creating Layer relu2
# I1208 15:12:23.560133 1908544256 net.cpp:394] relu2 <- conv2
# I1208 15:12:23.560148 1908544256 net.cpp:345] relu2 -> conv2 (in-place)
# I1208 15:12:23.560153 1908544256 net.cpp:96] Setting up relu2
# I1208 15:12:23.560158 1908544256 net.cpp:103] Top shape: 10 256 27 27 (1866240)
# I1208 15:12:23.560163 1908544256 net.cpp:67] Creating Layer pool2
# I1208 15:12:23.560168 1908544256 net.cpp:394] pool2 <- conv2
# I1208 15:12:23.560173 1908544256 net.cpp:356] pool2 -> pool2
# I1208 15:12:23.560179 1908544256 net.cpp:96] Setting up pool2
# I1208 15:12:23.560184 1908544256 net.cpp:103] Top shape: 10 256 13 13 (432640)
# I1208 15:12:23.560190 1908544256 net.cpp:67] Creating Layer norm2
# I1208 15:12:23.560194 1908544256 net.cpp:394] norm2 <- pool2
# I1208 15:12:23.560199 1908544256 net.cpp:356] norm2 -> norm2
# I1208 15:12:23.560205 1908544256 net.cpp:96] Setting up norm2
# I1208 15:12:23.560209 1908544256 net.cpp:103] Top shape: 10 256 13 13 (432640)
# I1208 15:12:23.560216 1908544256 net.cpp:67] Creating Layer conv3
# I1208 15:12:23.560220 1908544256 net.cpp:394] conv3 <- norm2
# I1208 15:12:23.560228 1908544256 net.cpp:356] conv3 -> conv3
# I1208 15:12:23.560235 1908544256 net.cpp:96] Setting up conv3
# I1208 15:12:23.562258 1908544256 net.cpp:103] Top shape: 10 384 13 13 (648960)
# I1208 15:12:23.562299 1908544256 net.cpp:67] Creating Layer relu3
# I1208 15:12:23.562304 1908544256 net.cpp:394] relu3 <- conv3
# I1208 15:12:23.562310 1908544256 net.cpp:345] relu3 -> conv3 (in-place)
# I1208 15:12:23.562316 1908544256 net.cpp:96] Setting up relu3
# I1208 15:12:23.562320 1908544256 net.cpp:103] Top shape: 10 384 13 13 (648960)
# I1208 15:12:23.562325 1908544256 net.cpp:67] Creating Layer conv4
# I1208 15:12:23.562330 1908544256 net.cpp:394] conv4 <- conv3
# I1208 15:12:23.562333 1908544256 net.cpp:356] conv4 -> conv4
# I1208 15:12:23.562340 1908544256 net.cpp:96] Setting up conv4
# I1208 15:12:23.563597 1908544256 net.cpp:103] Top shape: 10 384 13 13 (648960)
# I1208 15:12:23.563621 1908544256 net.cpp:67] Creating Layer relu4
# I1208 15:12:23.563626 1908544256 net.cpp:394] relu4 <- conv4
# I1208 15:12:23.563630 1908544256 net.cpp:345] relu4 -> conv4 (in-place)
# I1208 15:12:23.563635 1908544256 net.cpp:96] Setting up relu4
# I1208 15:12:23.563638 1908544256 net.cpp:103] Top shape: 10 384 13 13 (648960)
# I1208 15:12:23.563643 1908544256 net.cpp:67] Creating Layer conv5
# I1208 15:12:23.563647 1908544256 net.cpp:394] conv5 <- conv4
# I1208 15:12:23.563652 1908544256 net.cpp:356] conv5 -> conv5
# I1208 15:12:23.563657 1908544256 net.cpp:96] Setting up conv5
# I1208 15:12:23.564561 1908544256 net.cpp:103] Top shape: 10 256 13 13 (432640)
# I1208 15:12:23.564586 1908544256 net.cpp:67] Creating Layer relu5
# I1208 15:12:23.564590 1908544256 net.cpp:394] relu5 <- conv5
# I1208 15:12:23.564594 1908544256 net.cpp:345] relu5 -> conv5 (in-place)
# I1208 15:12:23.564599 1908544256 net.cpp:96] Setting up relu5
# I1208 15:12:23.564602 1908544256 net.cpp:103] Top shape: 10 256 13 13 (432640)
# I1208 15:12:23.564609 1908544256 net.cpp:67] Creating Layer pool5
# I1208 15:12:23.564611 1908544256 net.cpp:394] pool5 <- conv5
# I1208 15:12:23.564616 1908544256 net.cpp:356] pool5 -> pool5
# I1208 15:12:23.564631 1908544256 net.cpp:96] Setting up pool5
# I1208 15:12:23.564637 1908544256 net.cpp:103] Top shape: 10 256 6 6 (92160)
# I1208 15:12:23.564642 1908544256 net.cpp:67] Creating Layer fc6
# I1208 15:12:23.564646 1908544256 net.cpp:394] fc6 <- pool5
# I1208 15:12:23.564651 1908544256 net.cpp:356] fc6 -> fc6
# I1208 15:12:23.564656 1908544256 net.cpp:96] Setting up fc6
# I1208 15:12:23.645342 1908544256 net.cpp:103] Top shape: 10 4096 1 1 (40960)
# I1208 15:12:23.645390 1908544256 net.cpp:67] Creating Layer relu6
# I1208 15:12:23.645396 1908544256 net.cpp:394] relu6 <- fc6
# I1208 15:12:23.645402 1908544256 net.cpp:345] relu6 -> fc6 (in-place)
# I1208 15:12:23.645408 1908544256 net.cpp:96] Setting up relu6
# I1208 15:12:23.645412 1908544256 net.cpp:103] Top shape: 10 4096 1 1 (40960)
# I1208 15:12:23.645418 1908544256 net.cpp:67] Creating Layer drop6
# I1208 15:12:23.645422 1908544256 net.cpp:394] drop6 <- fc6
# I1208 15:12:23.645426 1908544256 net.cpp:345] drop6 -> fc6 (in-place)
# I1208 15:12:23.645431 1908544256 net.cpp:96] Setting up drop6
# I1208 15:12:23.645439 1908544256 net.cpp:103] Top shape: 10 4096 1 1 (40960)
# I1208 15:12:23.645454 1908544256 net.cpp:67] Creating Layer fc7
# I1208 15:12:23.645457 1908544256 net.cpp:394] fc7 <- fc6
# I1208 15:12:23.645462 1908544256 net.cpp:356] fc7 -> fc7
# I1208 15:12:23.645468 1908544256 net.cpp:96] Setting up fc7
# I1208 15:12:23.678093 1908544256 net.cpp:103] Top shape: 10 4096 1 1 (40960)
# I1208 15:12:23.678129 1908544256 net.cpp:67] Creating Layer relu7
# I1208 15:12:23.678134 1908544256 net.cpp:394] relu7 <- fc7
# I1208 15:12:23.678140 1908544256 net.cpp:345] relu7 -> fc7 (in-place)
# I1208 15:12:23.678145 1908544256 net.cpp:96] Setting up relu7
# I1208 15:12:23.678149 1908544256 net.cpp:103] Top shape: 10 4096 1 1 (40960)
# I1208 15:12:23.678154 1908544256 net.cpp:67] Creating Layer drop7
# I1208 15:12:23.678158 1908544256 net.cpp:394] drop7 <- fc7
# I1208 15:12:23.678166 1908544256 net.cpp:345] drop7 -> fc7 (in-place)
# I1208 15:12:23.678171 1908544256 net.cpp:96] Setting up drop7
# I1208 15:12:23.678175 1908544256 net.cpp:103] Top shape: 10 4096 1 1 (40960)
# I1208 15:12:23.678180 1908544256 net.cpp:67] Creating Layer fc-rcnn
# I1208 15:12:23.678184 1908544256 net.cpp:394] fc-rcnn <- fc7
# I1208 15:12:23.678189 1908544256 net.cpp:356] fc-rcnn -> fc-rcnn
# I1208 15:12:23.678205 1908544256 net.cpp:96] Setting up fc-rcnn
# I1208 15:12:23.679761 1908544256 net.cpp:103] Top shape: 10 200 1 1 (2000)
# I1208 15:12:23.679781 1908544256 net.cpp:172] fc-rcnn does not need backward computation.
# I1208 15:12:23.679785 1908544256 net.cpp:172] drop7 does not need backward computation.
# I1208 15:12:23.679788 1908544256 net.cpp:172] relu7 does not need backward computation.
# I1208 15:12:23.679791 1908544256 net.cpp:172] fc7 does not need backward computation.
# I1208 15:12:23.679795 1908544256 net.cpp:172] drop6 does not need backward computation.
# I1208 15:12:23.679798 1908544256 net.cpp:172] relu6 does not need backward computation.
# I1208 15:12:23.679802 1908544256 net.cpp:172] fc6 does not need backward computation.
# I1208 15:12:23.679805 1908544256 net.cpp:172] pool5 does not need backward computation.
# I1208 15:12:23.679808 1908544256 net.cpp:172] relu5 does not need backward computation.
# I1208 15:12:23.679811 1908544256 net.cpp:172] conv5 does not need backward computation.
# I1208 15:12:23.679816 1908544256 net.cpp:172] relu4 does not need backward computation.
# I1208 15:12:23.679818 1908544256 net.cpp:172] conv4 does not need backward computation.
# I1208 15:12:23.679821 1908544256 net.cpp:172] relu3 does not need backward computation.
# I1208 15:12:23.679834 1908544256 net.cpp:172] conv3 does not need backward computation.
# I1208 15:12:23.679837 1908544256 net.cpp:172] norm2 does not need backward computation.
# I1208 15:12:23.679841 1908544256 net.cpp:172] pool2 does not need backward computation.
# I1208 15:12:23.679844 1908544256 net.cpp:172] relu2 does not need backward computation.
# I1208 15:12:23.680066 1908544256 net.cpp:172] conv2 does not need backward computation.
# I1208 15:12:23.680084 1908544256 net.cpp:172] norm1 does not need backward computation.
# I1208 15:12:23.680088 1908544256 net.cpp:172] pool1 does not need backward computation.
# I1208 15:12:23.680091 1908544256 net.cpp:172] relu1 does not need backward computation.
# I1208 15:12:23.680095 1908544256 net.cpp:172] conv1 does not need backward computation.
# I1208 15:12:23.680099 1908544256 net.cpp:208] This network produces output fc-rcnn
# I1208 15:12:23.680114 1908544256 net.cpp:467] Collecting Learning Rate and Weight Decay.
# I1208 15:12:23.680119 1908544256 net.cpp:219] Network initialization done.
# I1208 15:12:23.680124 1908544256 net.cpp:220] Memory required for data: 62425920
# Loading input...
# selective_search_rcnn({'/Users/wuchenglin/git/caffe/examples/images/cat.jpg'}, '/var/folders/6b/qrklqfcd64x5rgshct2zyrdc0000gn/T/tmpnm9hwy.mat')
# matlab -nojvm -r "try; selective_search_rcnn({'/Users/wuchenglin/git/caffe/examples/images/cat.jpg'}, '/var/folders/6b/qrklqfcd64x5rgshct2zyrdc0000gn/T/tmpnm9hwy.mat'); catch; exit; end; exit"
# -----
# /Users/wuchenglin/git/selective_search_ijcv_with_python
# Processed 1673 windows in 65.078 s.
# /Library/Python/2.7/site-packages/pandas/io/pytables.py:2486: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->['prediction']]
#
#   warnings.warn(ws, PerformanceWarning)
# Saved to _temp/det_output.h5 in 0.047 s.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

print('')
df = pd.read_hdf('_temp/det_output.h5', 'df')
print(df.shape)
print(df.iloc[0])
# Out:
# (1673, 5)
# prediction    [-1.90234, -2.08308, -1.88053, -2.12834, -1.84...
# ymin                                                          0
# xmin                                                          0
# ymax                                                     360.04
# xmax                                                     480.04
# Name: /Users/wuchenglin/git/caffe/examples/images/cat.jpg, dtype: object

# %%
with open('../data/ilsvrc12/det_synset_words.txt') as f:
    labels_df = pd.DataFrame([
        {
            'synset_id': l.strip().split(' ')[0],
            'name': ' '.join(l.strip().split(' ')[1:]).split(',')[0]
        }
        for l in f.readlines()
    ])
labels_df.sort('synset_id')
predictions_df = pd.DataFrame(np.vstack(df.prediction.values), columns=labels_df['name'])
print(predictions_df.iloc[0])
# Out:
# name
# accordion      -1.902337
# airplane       -2.083077
# ant            -1.880534
# antelope       -2.128339
# apple          -1.849544
# armadillo      -2.146097
# artichoke      -2.050639
# axe            -1.941398
# baby bed       -2.159650
# backpack       -1.740651
# bagel          -2.072631
# balance beam   -1.893709
# banana         -2.065085
# band aid       -1.236814
# banjo          -1.733185
# ...
# trombone        -1.643601
# trumpet         -2.228507
# turtle          -2.513578
# tv or monitor   -1.889359
# unicycle        -1.918707
# vacuum          -1.937771
# violin          -1.974766
# volleyball      -1.677909
# waffle iron     -1.919281
# washer          -1.289852
# water bottle    -1.540026
# watercraft      -2.534053
# whale           -1.951540
# wine bottle     -2.321531
# zebra           -1.850923
# Name: 0, Length: 200, dtype: float32

# %%
max_s = predictions_df.max(0)
max_s.sort(ascending=False)
print(max_s[:10])

for index, i in enumerate(max_s):
    if i > 0:
        plot_patch(plt, max_s.index[i], colors, df, predictions_df)
    else:
        break
# Out:
# name
# domestic cat             0.314959
# monkey                  -0.306894
# flower pot              -0.570736
# fox                     -0.599925
# strawberry              -0.917276
# binder                  -0.936831
# salt or pepper shaker   -0.963058
# rabbit                  -0.968070
# head cabbage            -0.969243
# horse                   -0.983131
# dtype: float32
# 0 0.314959
# 1 -0.306894
# 2 -0.570736
# 3 -0.599925
# 4 -0.917276
# 5 -0.936831
# 6 -0.963058
# 7 -0.96807
# 8 -0.969243
# 9 -0.983131
# 10 -0.999847
# 11 -1.03383
# 12 -1.06248
# 13 -1.07424
# 14 -1.08694
# 15 -1.08932
# 16 -1.10515
# 17 -1.10777
# 18 -1.11327
# 19 -1.11461
# 20 -1.11594
# 21 -1.12311
# 22 -1.12738
# 23 -1.13003
# 24 -1.13073
# 25 -1.14597
# 26 -1.14932
# 27 -1.16602
# 28 -1.17506
# 29 -1.18591
# 30 -1.20237
# 31 -1.2032
# 32 -1.20337
# 33 -1.20506
# 34 -1.20812
# 35 -1.21181
# 36 -1.22378
# 37 -1.22407
# 38 -1.22591
# 39 -1.2272
# 40 -1.23025
# 41 -1.23204
# 42 -1.23362
# 43 -1.2392
# 44 -1.24178
# 45 -1.24286
# 46 -1.24327
# 47 -1.24613
# 48 -1.24875
# 49 -1.24912
# 50 -1.24946
# 51 -1.25068
# 52 -1.25893
# 53 -1.26176
# 54 -1.26659
# 55 -1.27147
# 56 -1.27222
# 57 -1.2735
# 58 -1.27565
# 59 -1.27735
# 60 -1.28152
# 61 -1.2846
# 62 -1.28859
# 63 -1.2968
# 64 -1.29965
# 65 -1.30155
# 66 -1.30242
# 67 -1.308
# 68 -1.31272
# 69 -1.31373
# 70 -1.31775
# 71 -1.32091
# 72 -1.32295
# 73 -1.3276
# 74 -1.32809
# 75 -1.33113
# 76 -1.33497
# 77 -1.34285
# 78 -1.3499
# 79 -1.35163
# 80 -1.36876
# 81 -1.3694
# 82 -1.37171
# 83 -1.37911
# 84 -1.37942
# 85 -1.38564
# 86 -1.39009
# 87 -1.39354
# 88 -1.40001
# 89 -1.40095
# 90 -1.4017
# 91 -1.40741
# 92 -1.41173
# 93 -1.41211
# 94 -1.41317
# 95 -1.41534
# 96 -1.41605
# 97 -1.4161
# 98 -1.42027
# 99 -1.42603
# 100 -1.4301
# 101 -1.4313
# 102 -1.43137
# 103 -1.44107
# 104 -1.44134
# 105 -1.44805
# 106 -1.45146
# 107 -1.45173
# 108 -1.4538
# 109 -1.45876
# 110 -1.46148
# 111 -1.46431
# 112 -1.46772
# 113 -1.46842
# 114 -1.46898
# 115 -1.47438
# 116 -1.47449
# 117 -1.47711
# 118 -1.48254
# 119 -1.49015
# 120 -1.49042
# 121 -1.50339
# 122 -1.50532
# 123 -1.50565
# 124 -1.50712
# 125 -1.51432
# 126 -1.51697
# 127 -1.51871
# 128 -1.52051
# 129 -1.52055
# 130 -1.52361
# 131 -1.5284
# 132 -1.53763
# 133 -1.54278
# 134 -1.54429
# 135 -1.55211
# 136 -1.55324
# 137 -1.55361
# 138 -1.55433
# 139 -1.5592
# 140 -1.56519
# 141 -1.57602
# 142 -1.57612
# 143 -1.58543
# 144 -1.59829
# 145 -1.60366
# 146 -1.6065
# 147 -1.60849
# 148 -1.6092
# 149 -1.61191
# 150 -1.61937
# 151 -1.62357
# 152 -1.62673
# 153 -1.62853
# 154 -1.62855
# 155 -1.63282
# 156 -1.64077
# 157 -1.64694
# 158 -1.65263
# 159 -1.65423
# 160 -1.65991
# 161 -1.66101
# 162 -1.66737
# 163 -1.66977
# 164 -1.67591
# 165 -1.69016
# 166 -1.69155
# 167 -1.70548
# 168 -1.70695
# 169 -1.71857
# 170 -1.71966
# 171 -1.7201
# 172 -1.72073
# 173 -1.72134
# 174 -1.73131
# 175 -1.74736
# 176 -1.74917
# 177 -1.77149
# 178 -1.77925
# 179 -1.79065
# 180 -1.80046
# 181 -1.81062
# 182 -1.81292
# 183 -1.82259
# 184 -1.83438
# 185 -1.84259
# 186 -1.8502
# 187 -1.85021
# 188 -1.86386
# 189 -1.86708
# 190 -1.88426
# 191 -1.88501
# 192 -1.93113
# 193 -1.94791
# 194 -1.94979
# 195 -2.01314
# 196 -2.07581
# 197 -2.0979
# 198 -2.30518
# 199 -2.33276

# %%
def nms_detections(dets, overlap=0.3):
    """
    Non-maximum suppression: Greedily select high-scoring detections and
    skip detections that are significantly covered by a previously
    selected detection.

    This version is translated from Matlab code by Tomasz Malisiewicz,
    who sped up Pedro Felzenszwalb's code.

    Parameters
    ----------
    dets: ndarray
        each row is ['xmin', 'ymin', 'xmax', 'ymax', 'score']
    overlap: float
        minimum overlap ratio (0.3 default)

    Output
    ------
    dets: ndarray
        remaining after suppression.
    """
    x1 = dets[:, 0]
    y1 = dets[:, 1]
    x2 = dets[:, 2]
    y2 = dets[:, 3]
    ind = np.argsort(dets[:, 4])

    w = x2 - x1
    h = y2 - y1
    area = (w * h).astype(float)

    pick = []
    while len(ind) > 0:
        i = ind[-1]
        pick.append(i)
        ind = ind[:-1]

        xx1 = np.maximum(x1[i], x1[ind])
        yy1 = np.maximum(y1[i], y1[ind])
        xx2 = np.minimum(x2[i], x2[ind])
        yy2 = np.minimum(y2[i], y2[ind])

        w = np.maximum(0., xx2 - xx1)
        h = np.maximum(0., yy2 - yy1)

        wh = w * h
        o = wh / (area[i] + area[ind] - wh)

        ind = ind[np.nonzero(o <= overlap)[0]]

    return dets[pick, :]

# %%
scores = predictions_df['domestic cat']
windows = df[['xmin', 'ymin', 'xmax', 'ymax']].values
# print sorted(scores, reverse=True)
dets = np.hstack((windows, scores[:, np.newaxis]))
nms_dets = nms_detections(dets)

# %%
im = plt.imread('images/cat.jpg')
plt.imshow(im)
currentAxis = plt.gca()
colors = ['r', 'b', 'y']
'''
for c, det in zip(colors, nms_dets[:3]):
    print c, det
    currentAxis.add_patch(
        plt.Rectangle((det[0], det[1]), det[2]-det[0], det[3]-det[1],
        fill=False, edgecolor=c, linewidth=5)
    )
print 'scores:', nms_dets[:3, 4]
'''

def plot_patch(plt, det_name, colors, df, predictions_df):
    scores = predictions_df[det_name]
    windows = df[['xmin', 'ymin', 'xmax', 'ymax']].values
    dets = np.hstack((windows, scores[:, np.newaxis]))
    nms_dets = nms_detections(dets)

    currentAxis = plt.gca()
    print len(scores), len(colors), len(nms_dets), len(dets)
    print ''
    print nms_dets[:len(colors)]
    print ''
    print dets[:len(colors)]
    for c, det in zip(colors, nms_dets[:len(colors)]):
        if det[4] < 0:
            break
        plt.text(det[0],
                 (det[3]-det[1])*9/10+det[1],
                 str(det[4])+'\n'+det_name,
                 bbox=dict(facecolor='white', alpha=0.5))
        #plt.text(det[0], (det[3]-det[1])*9/10+det[1], )
        currentAxis.add_patch(
            plt.Rectangle((det[0], det[1]), det[2]-det[0], det[3]-det[1],
            fill=False, edgecolor=c, linewidth=5)
        )
        print (det[0], det[1]), det[2]-det[0], det[3]-det[1]
    print 'scores:', nms_dets[:len(colors), 4]

for index, i in enumerate(max_s):
    if i > 0:
        plot_patch(plt, max_s.index[i], ['g', 'b', 'r'], df, predictions_df)
    else:
        break

plt.text(100, 100, r'$\mu=100,\ \sigma=15$')
# Out:
# 1673 3 244 1673
#
# [[  1.39200000e+02   2.11200000e+01   3.84040000e+02   3.49480000e+02
#     3.14959288e-01]
#  [  2.58240000e+02   3.00480000e+02   3.34120000e+02   3.50440000e+02
#    -1.71460688e+00]
#  [  1.57440000e+02   1.48800000e+02   2.71720000e+02   3.51400000e+02
#    -1.71644211e+00]]
#
# [[   0.            0.          480.04        360.04         -1.24007893]
#  [ 167.04         16.32        346.6         342.76         -0.84978676]
#  [  14.4          21.12        480.04        360.04         -0.98742545]]
# (139.19999999999999, 21.119999999999997) 244.84 328.36
# scores: [ 0.31495929 -1.71460688 -1.71644211]

# %%
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')

# %%
# !rm -rf _temp

# %%
print nms_dets[:3, 4]
print nms_dets[:3]
# Out:
# [ 0.31495929 -1.71460688 -1.71644211]
# [[  1.39200000e+02   2.11200000e+01   3.84040000e+02   3.49480000e+02
#     3.14959288e-01]
#  [  2.58240000e+02   3.00480000e+02   3.34120000e+02   3.50440000e+02
#    -1.71460688e+00]
#  [  1.57440000e+02   1.48800000e+02   2.71720000e+02   3.51400000e+02
#    -1.71644211e+00]]
